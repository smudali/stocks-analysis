# %% [markdown]
# ## Imports

# %%
# Read stocks
import yfinance as yf
# Dataframe
import pandas as pd
# To access NaN
import numpy as np

# %% [markdown]
# ## Constants

# %%
SECTOR = 'Technology'
INDUSTRY = 'Semiconductors'
# Stock symbols
SYMBOLS = 'NVDA,TSM,AVGO,AMD,INTC,QCOM,TXN,ADI,MU,ARM,MRVL,MPWR,MCHP,ON,STM'.split(',')
# Criteria + Score (computed)
CRITERIA = 'CR1,CR2,CR3,CR4,CR5,CR6,CR7,CR8,CR9,Score'.split(',')

# Human readable column names mapping for raw data
COLUMN_MAPPING_RAW={'Symbol': 'Symbol', 'Name': 'Name', 'CR1': 'Net Income', 'CR2': 'Return on Assets',
                'CR3': 'Op. Cash Flow', 'CR4': 'Quality of Earn', 'CR5': 'Long Term Debt',
                'CR6': 'Current Ratio', 'CR7': 'New Shares', 'CR8': 'Gross Margin', 'CR9': 'Asset TR'}

# Human readable column names mapping for score data - append Score dictionary item
COLUMN_MAPPING_SCORE = COLUMN_MAPPING_RAW | {'Score':'Score'}

# %% [markdown]
# ## Utility functions

# %%
def net_income(ticker):
    df = ticker.income_stmt
    return df.loc['Net Income'].iloc[0]

def roa(ticker):
    df = ticker.balance_sheet
    avg_assets = (df.loc['Total Assets'].iloc[0] + df.loc['Total Assets'].iloc[1])/2
    return round(net_income(ticker)/avg_assets, 2)

def ocf(ticker):
    df = ticker.cash_flow
    if 'Operating Cash Flow' in df.index:
        return df.loc['Operating Cash Flow'].iloc[0]
    else:
        # Calculate Operating Cash Flow using Free Cash Flow and Captial Expenditure
        # Take the absolute value for Captial Expenditure as yf returns as a negative number
        return df.loc['Free Cash Flow'].iloc[0] + abs(df.loc['Capital Expenditure']).iloc[0]

def ltdebt(ticker):
    df = ticker.balance_sheet
    return (df.loc['Long Term Debt'].iloc[1] - df.loc['Long Term Debt'].iloc[0])

def current_ratio(ticker):
    df = ticker.balance_sheet
    current_ratio_current = df.loc['Total Assets'].iloc[0]/df.loc['Total Liabilities Net Minority Interest'].iloc[0]
    current_ratio_prev = df.loc['Total Assets'].iloc[1]/df.loc['Total Liabilities Net Minority Interest'].iloc[1]
    return round((current_ratio_current - current_ratio_prev), 2)

def new_shares(ticker):
    df = ticker.balance_sheet
    return (df.loc['Common Stock'].iloc[1] - df.loc['Common Stock'].iloc[0])

def gross_margin(ticker):
    df = ticker.income_stmt
    gross_margin_current = df.loc['Gross Profit'].iloc[0]/ df.loc['Total Revenue'].iloc[0]
    gross_margin_prev = df.loc['Gross Profit'].iloc[1]/ df.loc['Total Revenue'].iloc[1]
    return (gross_margin_current - gross_margin_prev)

def asset_turnover_ratio(ticker):
    df_bs = ticker.balance_sheet
    y0, y1, y2 = df_bs.loc['Total Assets'].iloc[0], df_bs.loc['Total Assets'].iloc[1], df_bs.loc['Total Assets'].iloc[2]
    avg_asset_y0 = (y0 + y1)/2
    avg_asset_y1 = (y1 + y2)/2
    
    df_is = ticker.income_stmt
    tot_rvn_y0 = df_is.loc['Total Revenue'].iloc[0]/avg_asset_y0
    tot_rvn_y1 = df_is.loc['Total Revenue'].iloc[1]/avg_asset_y1

    return round((tot_rvn_y0 - tot_rvn_y1), 2)

# %% [markdown]
# ## Maps Criteria to Function

# %%
# Criteria name -> method
criteria_dict = {
    'CR1':net_income,
    'CR2':roa,
    'CR3':ocf,
    'CR5':ltdebt,
    'CR6':current_ratio,
    'CR7':new_shares,
    'CR8':gross_margin,
    'CR9':asset_turnover_ratio
}

# %% [markdown]
# ## Calculate Piotroski Score

# %%
def calculate_piotroski_score():
    # Dictionary to collect 9 criteria
    ps_criteria = {
        'Symbol':[],'Name':[],'CR1':[],'CR2':[],'CR3':[],'CR4':[],'CR5':[],
        'CR6':[],'CR7':[],'CR8':[],'CR9':[]
    }
    
    # Dictionary to collect raw data
    ps_criteria_data = {
        'Symbol':[],'Name':[],'CR1':[],'CR2':[],'CR3':[],'CR4':[],'CR5':[],
        'CR6':[],'CR7':[],'CR8':[],'CR9':[]
    }

    # Loop through symbol list
    for symbol in SYMBOLS:
        ticker = yf.Ticker(symbol)

        # Set symbol and name
        ps_criteria['Symbol'].append(ticker.info['symbol'])
        ps_criteria['Name'].append(ticker.info['longName'])
        
        ps_criteria_data['Symbol'].append(ticker.info['symbol'])
        ps_criteria_data['Name'].append(ticker.info['longName'])

        # Set criteria
        for key, value in criteria_dict.items():
            try:
                # Uses the command pattern to call the appropriate method
                result = value(ticker)
                ps_criteria_data[key].append(result)
                # Special adjustment for CR7 - if there re no new shares, i.e, difference between current and previous is 0 then add 1 as well
                if key == 'CR7':
                    ps_criteria[key].append(1 if result >= 0 else 0)
                else:
                    # Process with other CRs
                    ps_criteria[key].append(1 if result > 0 else 0)
            except (KeyError, IndexError) as err:
                # Error encountered, due to missing data"
                print(err)
                ps_criteria[key].append(0)
                ps_criteria_data[key].append(np.nan)

        # CR4 - handle it differently as it doesn't invoke a method
        # CR4 - Cash flow from operations being greater than net income (quality of earnings)
        if ps_criteria_data['CR3'][-1] > ps_criteria_data['CR1'][-1]:
            ps_criteria['CR4'].append(1)
            ps_criteria_data['CR4'].append(1)
        else:
            # Set criteria and raw data to false (0)
            ps_criteria['CR4'].append(0)
            ps_criteria_data['CR4'].append(0)
    return ps_criteria, ps_criteria_data

# %% [markdown]
# ## Data Frames for Score and Raw data

# %%
ps_criteria, ps_criteria_data = calculate_piotroski_score()
ps_criteria_df = pd.DataFrame(ps_criteria)
# Add ranking scores to get the total score
ps_criteria_df['Score'] = ps_criteria_df[CRITERIA[:-1]].sum(axis=1)
ps_criteria_df
# Out:
# 'Long Term Debt'
# single positional indexer is out-of-bounds
# 'Long Term Debt'
#    Symbol                                               Name  CR1  CR2  CR3  \
# 0    NVDA                                 NVIDIA Corporation    1    1    1
# 1     TSM  Taiwan Semiconductor Manufacturing Company Lim...    1    1    1
# 2    AVGO                                      Broadcom Inc.    1    1    1
# 3     AMD                       Advanced Micro Devices, Inc.    1    1    1
# 4    INTC                                  Intel Corporation    1    1    1
# 5    QCOM                              QUALCOMM Incorporated    1    1    1
# 6     TXN                     Texas Instruments Incorporated    1    1    1
# 7     ADI                               Analog Devices, Inc.    1    1    1
# 8      MU                            Micron Technology, Inc.    0    0    1
# 9     ARM                                   Arm Holdings plc    1    1    1
# 10   MRVL                           Marvell Technology, Inc.    0    0    1
# 11   MPWR                     Monolithic Power Systems, Inc.    1    1    1
# 12   MCHP                  Microchip Technology Incorporated    1    1    1
# 13     ON                       ON Semiconductor Corporation    1    1    1
# 14    STM                            STMicroelectronics N.V.    1    1    1
#
#     CR4  CR5  CR6  CR7  CR8  CR9  Score
# 0     1    1    0    1    0    0      6
# 1     1    0    1    1    1    1      8
# 2     1    1    1    1    1    1      9
# 3     1    1    1    0    1    0      7
# 4     1    0    1    0    0    0      5
# 5     1    0    1    0    0    0      5
# 6     0    0    0    1    0    0      4
# 7     1    1    1    1    1    1      9
# 8     1    0    0    0    0    0      2
# 9     1    0    1    1    1    0      7
# 10    1    1    0    1    1    0      5
# 11    0    0    1    0    1    1      6
# 12    1    1    1    1    1    1      9
# 13    1    0    1    0    1    1      7
# 14    1    0    1    1    1    1      8

# %%
ps_criteria_data_df = pd.DataFrame(ps_criteria_data)
ps_criteria_data_df
# Out:
#    Symbol                                               Name           CR1  \
# 0    NVDA                                 NVIDIA Corporation  4.368000e+09
# 1     TSM  Taiwan Semiconductor Manufacturing Company Lim...  9.929234e+11
# 2    AVGO                                      Broadcom Inc.  1.408200e+10
# 3     AMD                       Advanced Micro Devices, Inc.  8.540000e+08
# 4    INTC                                  Intel Corporation  1.689000e+09
# 5    QCOM                              QUALCOMM Incorporated  7.232000e+09
# 6     TXN                     Texas Instruments Incorporated  6.510000e+09
# 7     ADI                               Analog Devices, Inc.  3.314579e+09
# 8      MU                            Micron Technology, Inc. -5.833000e+09
# 9     ARM                                   Arm Holdings plc  5.240000e+08
# 10   MRVL                           Marvell Technology, Inc. -1.635000e+08
# 11   MPWR                     Monolithic Power Systems, Inc.  4.376720e+08
# 12   MCHP                  Microchip Technology Incorporated  2.237700e+09
# 13     ON                       ON Semiconductor Corporation  1.902200e+09
# 14    STM                            STMicroelectronics N.V.  3.960000e+09
#
#      CR2           CR3  CR4           CR5   CR6           CR7       CR8   CR9
# 0   0.10  5.641000e+09    1  1.243000e+09 -0.36  1.000000e+06 -0.080001 -0.11
# 1   0.23  1.610599e+12    1 -2.257167e+11  0.06  0.000000e+00  0.079320  0.03
# 2   0.19  1.808500e+10    1  1.436000e+09  0.04  0.000000e+00  0.023847  0.04
# 3   0.01  1.667000e+09    1  7.500000e+08  0.39 -1.000000e+06  0.011939 -0.26
# 4   0.01  1.147100e+10    1 -9.294000e+09  0.04 -5.069000e+09 -0.025714 -0.07
# 5   0.14  1.129900e+10    1 -9.470000e+08  0.15 -2.950000e+08 -0.021414 -0.26
# 6   0.22  6.420000e+09    0 -2.389000e+09 -0.06  0.000000e+00 -0.058613 -0.18
# 7   0.07  4.817634e+09    1  6.461680e+08  0.05  2.168000e+06  0.013159  0.01
# 8  -0.09  1.559000e+09    1 -5.923000e+09 -0.86 -1.000000e+06 -0.542970 -0.25
# 9   0.08  7.390000e+08    1           NaN  0.24  0.000000e+00  0.008898   NaN
# 10 -0.01  1.288800e+09    1  5.771000e+08 -0.18  0.000000e+00  0.042103 -0.01
# 11  0.24  2.466740e+08    0           NaN  0.64 -1.720500e+08  0.016901  0.12
# 12  0.14  3.621000e+09    1  2.645700e+09  0.09  1.000000e+05  0.022863  0.10
# 13  0.18  2.633100e+09    1 -1.318000e+08  0.16 -1.000000e+05  0.086956  0.03
# 14  0.22  5.202000e+09    1 -1.460000e+08  0.29  0.000000e+00  0.056035  0.06

# %% [markdown]
# ## Utility method to convert a number to human readable format
# #### https://stackoverflow.com/questions/579310/formatting-long-numbers-as-strings

# %%
def human_format(num):
    if np.isnan(num):
        return 'nan'
    # Check for zero or else it will return an empty string
    elif num == 0:
        return '0'
    num = float('{:.3g}'.format(num))
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    return '{}{}'.format('{:f}'.format(num).rstrip('0.'), ['', 'K', 'M', 'B', 'T'][magnitude])

# %% [markdown]
# ## Add Styles to Score DF

# %%
def make_pretty_score(styler):
    # Columns with 0 decimal points
    zero_formats = {}
    for idx in range(1,10):
        zero_formats[f'CR{idx}']='{:.0f}'        
    styler.format(zero_formats)
    
    # Hide index
    styler.hide(axis='index')

    # Left text alignment for Symbol and Name columns
    styler.set_properties(subset=['Symbol', 'Name'], **{'text-align': 'left'})
    # Center alignment for the rest
    styler.set_properties(subset=CRITERIA, **{'text-align': 'center'})

    # Set background gradients
    styler.background_gradient(subset=['Score'], cmap='PiYG')
    
    # Borders
    styler.set_properties(**{'border': '1px solid grey'})
    return styler

def column_formatter_score(name):
    return COLUMN_MAPPING_SCORE[name]

# %% [markdown]
# ## Apply styles to Score DF

# %%
# Add table caption and styles to DF
ps_criteria_df.style.pipe(make_pretty_score).set_caption(f'Piotroski Score {SECTOR} - {INDUSTRY}').set_table_styles(
    [{'selector': 'th.col_heading', 'props': [('text-align', 'center'),
                                              ('color', 'bisque'), ('font-size', '10pt')]},
     {'selector': 'td', 'props': [('font-size', '10pt')]},
     {'selector': 'caption', 'props': [('text-align', 'center'), ('color', 'goldenrod'),
                                       ('font-size', '14pt'), ('font-weight', 'bold')]}]).format_index(column_formatter_score, axis=1)
# Out:
# <style type="text/css">
# #T_7db8a th.col_heading {
#   text-align: center;
#   color: bisque;
#   font-size: 10pt;
# }
# #T_7db8a td {
#   font-size: 10pt;
# }
# #T_7db8a caption {
#   text-align: center;
#   color: goldenrod;
#   font-size: 14pt;
#   font-weight: bold;
# }
# #T_7db8a_row0_col0, #T_7db8a_row0_col1, #T_7db8a_row1_col0, #T_7db8a_row1_col1, #T_7db8a_row2_col0, #T_7db8a_row2_col1, #T_7db8a_row3_col0, #T_7db8a_row3_col1, #T_7db8a_row4_col0, #T_7db8a_row4_col1, #T_7db8a_row5_col0, #T_7db8a_row5_col1, #T_7db8a_row6_col0, #T_7db8a_row6_col1, #T_7db8a_row7_col0, #T_7db8a_row7_col1, #T_7db8a_row8_col0, #T_7db8a_row8_col1, #T_7db8a_row9_col0, #T_7db8a_row9_col1, #T_7db8a_row10_col0, #T_7db8a_row10_col1, #T_7db8a_row11_col0, #T_7db8a_row11_col1, #T_7db8a_row12_col0, #T_7db8a_row12_col1, #T_7db8a_row13_col0, #T_7db8a_row13_col1, #T_7db8a_row14_col0, #T_7db8a_row14_col1 {
#   text-align: left;
#   border: 1px solid grey;
# }
# #T_7db8a_row0_col2, #T_7db8a_row0_col3, #T_7db8a_row0_col4, #T_7db8a_row0_col5, #T_7db8a_row0_col6, #T_7db8a_row0_col7, #T_7db8a_row0_col8, #T_7db8a_row0_col9, #T_7db8a_row0_col10, #T_7db8a_row1_col2, #T_7db8a_row1_col3, #T_7db8a_row1_col4, #T_7db8a_row1_col5, #T_7db8a_row1_col6, #T_7db8a_row1_col7, #T_7db8a_row1_col8, #T_7db8a_row1_col9, #T_7db8a_row1_col10, #T_7db8a_row2_col2, #T_7db8a_row2_col3, #T_7db8a_row2_col4, #T_7db8a_row2_col5, #T_7db8a_row2_col6, #T_7db8a_row2_col7, #T_7db8a_row2_col8, #T_7db8a_row2_col9, #T_7db8a_row2_col10, #T_7db8a_row3_col2, #T_7db8a_row3_col3, #T_7db8a_row3_col4, #T_7db8a_row3_col5, #T_7db8a_row3_col6, #T_7db8a_row3_col7, #T_7db8a_row3_col8, #T_7db8a_row3_col9, #T_7db8a_row3_col10, #T_7db8a_row4_col2, #T_7db8a_row4_col3, #T_7db8a_row4_col4, #T_7db8a_row4_col5, #T_7db8a_row4_col6, #T_7db8a_row4_col7, #T_7db8a_row4_col8, #T_7db8a_row4_col9, #T_7db8a_row4_col10, #T_7db8a_row5_col2, #T_7db8a_row5_col3, #T_7db8a_row5_col4, #T_7db8a_row5_col5, #T_7db8a_row5_col6, #T_7db8a_row5_col7, #T_7db8a_row5_col8, #T_7db8a_row5_col9, #T_7db8a_row5_col10, #T_7db8a_row6_col2, #T_7db8a_row6_col3, #T_7db8a_row6_col4, #T_7db8a_row6_col5, #T_7db8a_row6_col6, #T_7db8a_row6_col7, #T_7db8a_row6_col8, #T_7db8a_row6_col9, #T_7db8a_row6_col10, #T_7db8a_row7_col2, #T_7db8a_row7_col3, #T_7db8a_row7_col4, #T_7db8a_row7_col5, #T_7db8a_row7_col6, #T_7db8a_row7_col7, #T_7db8a_row7_col8, #T_7db8a_row7_col9, #T_7db8a_row7_col10, #T_7db8a_row8_col2, #T_7db8a_row8_col3, #T_7db8a_row8_col4, #T_7db8a_row8_col5, #T_7db8a_row8_col6, #T_7db8a_row8_col7, #T_7db8a_row8_col8, #T_7db8a_row8_col9, #T_7db8a_row8_col10, #T_7db8a_row9_col2, #T_7db8a_row9_col3, #T_7db8a_row9_col4, #T_7db8a_row9_col5, #T_7db8a_row9_col6, #T_7db8a_row9_col7, #T_7db8a_row9_col8, #T_7db8a_row9_col9, #T_7db8a_row9_col10, #T_7db8a_row10_col2, #T_7db8a_row10_col3, #T_7db8a_row10_col4, #T_7db8a_row10_col5, #T_7db8a_row10_col6, #T_7db8a_row10_col7, #T_7db8a_row10_col8, #T_7db8a_row10_col9, #T_7db8a_row10_col10, #T_7db8a_row11_col2, #T_7db8a_row11_col3, #T_7db8a_row11_col4, #T_7db8a_row11_col5, #T_7db8a_row11_col6, #T_7db8a_row11_col7, #T_7db8a_row11_col8, #T_7db8a_row11_col9, #T_7db8a_row11_col10, #T_7db8a_row12_col2, #T_7db8a_row12_col3, #T_7db8a_row12_col4, #T_7db8a_row12_col5, #T_7db8a_row12_col6, #T_7db8a_row12_col7, #T_7db8a_row12_col8, #T_7db8a_row12_col9, #T_7db8a_row12_col10, #T_7db8a_row13_col2, #T_7db8a_row13_col3, #T_7db8a_row13_col4, #T_7db8a_row13_col5, #T_7db8a_row13_col6, #T_7db8a_row13_col7, #T_7db8a_row13_col8, #T_7db8a_row13_col9, #T_7db8a_row13_col10, #T_7db8a_row14_col2, #T_7db8a_row14_col3, #T_7db8a_row14_col4, #T_7db8a_row14_col5, #T_7db8a_row14_col6, #T_7db8a_row14_col7, #T_7db8a_row14_col8, #T_7db8a_row14_col9, #T_7db8a_row14_col10 {
#   text-align: center;
#   border: 1px solid grey;
# }
# #T_7db8a_row0_col11, #T_7db8a_row11_col11 {
#   text-align: center;
#   background-color: #ebf6db;
#   color: #000000;
#   border: 1px solid grey;
# }
# #T_7db8a_row1_col11, #T_7db8a_row14_col11 {
#   text-align: center;
#   background-color: #62a32e;
#   color: #f1f1f1;
#   border: 1px solid grey;
# }
# #T_7db8a_row2_col11, #T_7db8a_row7_col11, #T_7db8a_row12_col11 {
#   text-align: center;
#   background-color: #276419;
#   color: #f1f1f1;
#   border: 1px solid grey;
# }
# #T_7db8a_row3_col11, #T_7db8a_row9_col11, #T_7db8a_row13_col11 {
#   text-align: center;
#   background-color: #b0dc7d;
#   color: #000000;
#   border: 1px solid grey;
# }
# #T_7db8a_row4_col11, #T_7db8a_row5_col11, #T_7db8a_row10_col11 {
#   text-align: center;
#   background-color: #fbe6f1;
#   color: #000000;
#   border: 1px solid grey;
# }
# #T_7db8a_row6_col11 {
#   text-align: center;
#   background-color: #eeadd4;
#   color: #000000;
#   border: 1px solid grey;
# }
# #T_7db8a_row8_col11 {
#   text-align: center;
#   background-color: #8e0152;
#   color: #f1f1f1;
#   border: 1px solid grey;
# }
# </style>
# <table id="T_7db8a">
#   <caption>Piotroski Score Technology - Semiconductors</caption>
#   <thead>
#     <tr>
#       <th id="T_7db8a_level0_col0" class="col_heading level0 col0" >Symbol</th>
#       <th id="T_7db8a_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_7db8a_level0_col2" class="col_heading level0 col2" >Net Income</th>
#       <th id="T_7db8a_level0_col3" class="col_heading level0 col3" >Return on Assets</th>
#       <th id="T_7db8a_level0_col4" class="col_heading level0 col4" >Op. Cash Flow</th>
#       <th id="T_7db8a_level0_col5" class="col_heading level0 col5" >Quality of Earn</th>
#       <th id="T_7db8a_level0_col6" class="col_heading level0 col6" >Long Term Debt</th>
#       <th id="T_7db8a_level0_col7" class="col_heading level0 col7" >Current Ratio</th>
#       <th id="T_7db8a_level0_col8" class="col_heading level0 col8" >New Shares</th>
#       <th id="T_7db8a_level0_col9" class="col_heading level0 col9" >Gross Margin</th>
#       <th id="T_7db8a_level0_col10" class="col_heading level0 col10" >Asset TR</th>
#       <th id="T_7db8a_level0_col11" class="col_heading level0 col11" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7db8a_row0_col0" class="data row0 col0" >NVDA</td>
#       <td id="T_7db8a_row0_col1" class="data row0 col1" >NVIDIA Corporation</td>
#       <td id="T_7db8a_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_7db8a_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_7db8a_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_7db8a_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_7db8a_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_7db8a_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_7db8a_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_7db8a_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_7db8a_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_7db8a_row0_col11" class="data row0 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_7db8a_row1_col0" class="data row1 col0" >TSM</td>
#       <td id="T_7db8a_row1_col1" class="data row1 col1" >Taiwan Semiconductor Manufacturing Company Limited</td>
#       <td id="T_7db8a_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_7db8a_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_7db8a_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_7db8a_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_7db8a_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_7db8a_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_7db8a_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_7db8a_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_7db8a_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_7db8a_row1_col11" class="data row1 col11" >8</td>
#     </tr>
#     <tr>
#       <td id="T_7db8a_row2_col0" class="data row2 col0" >AVGO</td>
#       <td id="T_7db8a_row2_col1" class="data row2 col1" >Broadcom Inc.</td>
#       <td id="T_7db8a_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_7db8a_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_7db8a_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_7db8a_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_7db8a_row2_col6" class="data row2 co

# %% [markdown]
# ## Add Styles to Raw DF

# %%
def make_pretty_raw(styler):
    # Columns with 2 decimal points
    styler.format({'CR2':'{:.2f}','CR6':'{:.2f}','CR8':'{:.2f}','CR9':'{:.2f}'})
    
    # Apply human_fomrat for cols
    styler.format(human_format, subset=['CR1','CR3','CR5','CR7'])
    
    # Hide index
    styler.hide(axis='index')

    # Left text alignment for some columns
    styler.set_properties(subset=['Symbol', 'Name'], **{'text-align': 'left'})

    # Borders
    styler.set_properties(**{'border': '1px solid grey'})
    return styler

def column_formatter_raw(name):
    return COLUMN_MAPPING_RAW[name]

# %% [markdown]
# ## Apply styles to Raw DF

# %%
# Add table caption and styles to DF
ps_criteria_data_df.style.pipe(make_pretty_raw).set_caption(f'Data for Piotroski Score {SECTOR} - {INDUSTRY}').set_table_styles(
    [{'selector': 'th.col_heading', 'props': [('text-align', 'center'),
                                              ('color', 'bisque'), ('font-size', '10pt')]},
     {'selector': 'td', 'props': [('font-size', '10pt')]},
     {'selector': 'caption', 'props': [('text-align', 'center'), ('color', 'goldenrod'),
                                       ('font-size', '14pt'), ('font-weight', 'bold')]}]).format_index(column_formatter_raw, axis=1)
# Out:
# <style type="text/css">
# #T_ea852 th.col_heading {
#   text-align: center;
#   color: bisque;
#   font-size: 10pt;
# }
# #T_ea852 td {
#   font-size: 10pt;
# }
# #T_ea852 caption {
#   text-align: center;
#   color: goldenrod;
#   font-size: 14pt;
#   font-weight: bold;
# }
# #T_ea852_row0_col0, #T_ea852_row0_col1, #T_ea852_row1_col0, #T_ea852_row1_col1, #T_ea852_row2_col0, #T_ea852_row2_col1, #T_ea852_row3_col0, #T_ea852_row3_col1, #T_ea852_row4_col0, #T_ea852_row4_col1, #T_ea852_row5_col0, #T_ea852_row5_col1, #T_ea852_row6_col0, #T_ea852_row6_col1, #T_ea852_row7_col0, #T_ea852_row7_col1, #T_ea852_row8_col0, #T_ea852_row8_col1, #T_ea852_row9_col0, #T_ea852_row9_col1, #T_ea852_row10_col0, #T_ea852_row10_col1, #T_ea852_row11_col0, #T_ea852_row11_col1, #T_ea852_row12_col0, #T_ea852_row12_col1, #T_ea852_row13_col0, #T_ea852_row13_col1, #T_ea852_row14_col0, #T_ea852_row14_col1 {
#   text-align: left;
#   border: 1px solid grey;
# }
# #T_ea852_row0_col2, #T_ea852_row0_col3, #T_ea852_row0_col4, #T_ea852_row0_col5, #T_ea852_row0_col6, #T_ea852_row0_col7, #T_ea852_row0_col8, #T_ea852_row0_col9, #T_ea852_row0_col10, #T_ea852_row1_col2, #T_ea852_row1_col3, #T_ea852_row1_col4, #T_ea852_row1_col5, #T_ea852_row1_col6, #T_ea852_row1_col7, #T_ea852_row1_col8, #T_ea852_row1_col9, #T_ea852_row1_col10, #T_ea852_row2_col2, #T_ea852_row2_col3, #T_ea852_row2_col4, #T_ea852_row2_col5, #T_ea852_row2_col6, #T_ea852_row2_col7, #T_ea852_row2_col8, #T_ea852_row2_col9, #T_ea852_row2_col10, #T_ea852_row3_col2, #T_ea852_row3_col3, #T_ea852_row3_col4, #T_ea852_row3_col5, #T_ea852_row3_col6, #T_ea852_row3_col7, #T_ea852_row3_col8, #T_ea852_row3_col9, #T_ea852_row3_col10, #T_ea852_row4_col2, #T_ea852_row4_col3, #T_ea852_row4_col4, #T_ea852_row4_col5, #T_ea852_row4_col6, #T_ea852_row4_col7, #T_ea852_row4_col8, #T_ea852_row4_col9, #T_ea852_row4_col10, #T_ea852_row5_col2, #T_ea852_row5_col3, #T_ea852_row5_col4, #T_ea852_row5_col5, #T_ea852_row5_col6, #T_ea852_row5_col7, #T_ea852_row5_col8, #T_ea852_row5_col9, #T_ea852_row5_col10, #T_ea852_row6_col2, #T_ea852_row6_col3, #T_ea852_row6_col4, #T_ea852_row6_col5, #T_ea852_row6_col6, #T_ea852_row6_col7, #T_ea852_row6_col8, #T_ea852_row6_col9, #T_ea852_row6_col10, #T_ea852_row7_col2, #T_ea852_row7_col3, #T_ea852_row7_col4, #T_ea852_row7_col5, #T_ea852_row7_col6, #T_ea852_row7_col7, #T_ea852_row7_col8, #T_ea852_row7_col9, #T_ea852_row7_col10, #T_ea852_row8_col2, #T_ea852_row8_col3, #T_ea852_row8_col4, #T_ea852_row8_col5, #T_ea852_row8_col6, #T_ea852_row8_col7, #T_ea852_row8_col8, #T_ea852_row8_col9, #T_ea852_row8_col10, #T_ea852_row9_col2, #T_ea852_row9_col3, #T_ea852_row9_col4, #T_ea852_row9_col5, #T_ea852_row9_col6, #T_ea852_row9_col7, #T_ea852_row9_col8, #T_ea852_row9_col9, #T_ea852_row9_col10, #T_ea852_row10_col2, #T_ea852_row10_col3, #T_ea852_row10_col4, #T_ea852_row10_col5, #T_ea852_row10_col6, #T_ea852_row10_col7, #T_ea852_row10_col8, #T_ea852_row10_col9, #T_ea852_row10_col10, #T_ea852_row11_col2, #T_ea852_row11_col3, #T_ea852_row11_col4, #T_ea852_row11_col5, #T_ea852_row11_col6, #T_ea852_row11_col7, #T_ea852_row11_col8, #T_ea852_row11_col9, #T_ea852_row11_col10, #T_ea852_row12_col2, #T_ea852_row12_col3, #T_ea852_row12_col4, #T_ea852_row12_col5, #T_ea852_row12_col6, #T_ea852_row12_col7, #T_ea852_row12_col8, #T_ea852_row12_col9, #T_ea852_row12_col10, #T_ea852_row13_col2, #T_ea852_row13_col3, #T_ea852_row13_col4, #T_ea852_row13_col5, #T_ea852_row13_col6, #T_ea852_row13_col7, #T_ea852_row13_col8, #T_ea852_row13_col9, #T_ea852_row13_col10, #T_ea852_row14_col2, #T_ea852_row14_col3, #T_ea852_row14_col4, #T_ea852_row14_col5, #T_ea852_row14_col6, #T_ea852_row14_col7, #T_ea852_row14_col8, #T_ea852_row14_col9, #T_ea852_row14_col10 {
#   border: 1px solid grey;
# }
# </style>
# <table id="T_ea852">
#   <caption>Data for Piotroski Score Technology - Semiconductors</caption>
#   <thead>
#     <tr>
#       <th id="T_ea852_level0_col0" class="col_heading level0 col0" >Symbol</th>
#       <th id="T_ea852_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_ea852_level0_col2" class="col_heading level0 col2" >Net Income</th>
#       <th id="T_ea852_level0_col3" class="col_heading level0 col3" >Return on Assets</th>
#       <th id="T_ea852_level0_col4" class="col_heading level0 col4" >Op. Cash Flow</th>
#       <th id="T_ea852_level0_col5" class="col_heading level0 col5" >Quality of Earn</th>
#       <th id="T_ea852_level0_col6" class="col_heading level0 col6" >Long Term Debt</th>
#       <th id="T_ea852_level0_col7" class="col_heading level0 col7" >Current Ratio</th>
#       <th id="T_ea852_level0_col8" class="col_heading level0 col8" >New Shares</th>
#       <th id="T_ea852_level0_col9" class="col_heading level0 col9" >Gross Margin</th>
#       <th id="T_ea852_level0_col10" class="col_heading level0 col10" >Asset TR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ea852_row0_col0" class="data row0 col0" >NVDA</td>
#       <td id="T_ea852_row0_col1" class="data row0 col1" >NVIDIA Corporation</td>
#       <td id="T_ea852_row0_col2" class="data row0 col2" >4.37B</td>
#       <td id="T_ea852_row0_col3" class="data row0 col3" >0.10</td>
#       <td id="T_ea852_row0_col4" class="data row0 col4" >5.64B</td>
#       <td id="T_ea852_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_ea852_row0_col6" class="data row0 col6" >1.24B</td>
#       <td id="T_ea852_row0_col7" class="data row0 col7" >-0.36</td>
#       <td id="T_ea852_row0_col8" class="data row0 col8" >1M</td>
#       <td id="T_ea852_row0_col9" class="data row0 col9" >-0.08</td>
#       <td id="T_ea852_row0_col10" class="data row0 col10" >-0.11</td>
#     </tr>
#     <tr>
#       <td id="T_ea852_row1_col0" class="data row1 col0" >TSM</td>
#       <td id="T_ea852_row1_col1" class="data row1 col1" >Taiwan Semiconductor Manufacturing Company Limited</td>
#       <td id="T_ea852_row1_col2" class="data row1 col2" >993B</td>
#       <td id="T_ea852_row1_col3" class="data row1 col3" >0.23</td>
#       <td id="T_ea852_row1_col4" class="data row1 col4" >1.61T</td>
#       <td id="T_ea852_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_ea852_row1_col6" class="data row1 col6" >-226B</td>
#       <td id="T_ea852_row1_col7" class="data row1 col7" >0.06</td>
#       <td id="T_ea852_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_ea852_row1_col9" class="data row1 col9" >0.08</td>
#       <td id="T_ea852_row1_col10" class="data row1 col10" >0.03</td>
#     </tr>
#     <tr>
#       <td id="T_ea852_row2_col0" class="data row2 col0" >AVGO</td>
#       <td id="T_ea852_row2_col1" class="data row2 col1" >Broadcom Inc.</td>
#       <td id="T_ea852_row2_col2" class="data row2 col2" >14.1B</td>
#       <td id="T_ea852_row2_col3" class="data row2 col3" >0.19</td>
#       <td id="T_ea852_row2_col4" class="data row2 col4" >18.1B</td>
#       <td id="T_ea852_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_ea852_row2_col6" class="data row2 col6" >1.44B</td>
#       <td id="T_ea852_row2_col7" class="data row2 col7" >0.04</td>
#       <td id="T_ea852_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_ea852_row2_col9" class="data row2 col9" >0.02</td>
#       <td id="T_ea852_row2_col10" class="data row2 col10" >0.04</td>
#     </tr>
#     <tr>
#       <td id="T_ea852_row3_col0" class="data row3 col0" >AMD</td>
#       <td id="T_ea852_row3_col1" class="data row3 col1" >Advanced Micro Devices, Inc.</td>
#       <td id="T_ea852_row3_col2" class="data row3 col2" >854M</td>
#       <td id="T_ea852_row3_col3" class="data row3 col3" >0.01</td>
#       <td id="T_ea852_row3_col4" class="data row3 col4" >1.67B</td>
#       <td id="T_ea852_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_ea852_row3_col6" class="data row3 col6" >75M</td>
#       <td id="T_ea852_row3_col7" class="data row3 col7" >0.39</td>
#       <td id="T_ea852_row3_col8" class="data row3 col8" >-1M</td>
#       <td id="T_ea852_row3_col9" class="data row3 col9" >0.01</td>
#       <td id="T_ea852_row3_col10" class="data row3 col10" >-0.26</td>
#     </tr>
#     <tr>
#       <td id="T_ea852_row4_col0" class="data row4 col0" >INTC</td>
#       <td id="T_ea852_r
